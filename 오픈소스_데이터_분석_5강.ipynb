# %% [markdown]
# <a href="https://colab.research.google.com/github/yoonseull/Data-Analysis-with-Open-Source/blob/main/%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_5%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오픈소스 기반 데이터 분석 5강 - 데이터 저장

# %% [markdown]
# ## 5-1 CSV 형식 저장

# %%
import pandas as pd

data = {
    'student_id': [101, 102, 103, 104, 105],
    'database_score': [85, 76, 92, 63, 88],
    'cloudcomputing_score': [78, 82, 95, 70, 84],
    'python_score': [92, 78, 85, 75, 91],
    'watch_rate': [0.95, 0.87, 0.99, 0.80, 0.93]
}
## DataFrame 생성
df = pd.DataFrame(data)
df

## CSV 형식 저장
df.to_csv('student_analysis.csv', encoding='utf-8', index=False) #행인덱스 제외하고 저장하기 위해 false

# %% [markdown]
# ## 5-2 JSON 형식 저장

# %%
### 라이브러리 임포트
import json
import pandas as pd

data = {
    "이름": "홍길동",
    "나이": 25,
    "거주지": "서울",
    "관심사": ["프로그래밍", "데이터 분석", "여행"]
}

## json.dump를 이용한 저장
with open('output.json', mode='w', encoding='utf-8') as f:
    #json은 기본적으로 한글 저장하지 않고 아스키코드만 저장하게 기본 설정 되어있어서 아스키코드로 강제하는 걸 false로 설정해줘야 팡리 열었을때 한글로 잘 보이게 됨
    json.dump(data, f, indent=4, ensure_ascii=False)

## DataFrame을 이용한 저장
'''레코드 단위로 저장
df = pd.DataFrame(data)
df.to_json('output_df.json', orient='records', indent=4, force_ascii=False) #같은 기능을 하는 옵션이지만 이름 다름
'''
#컬럼 단위로 하나의 객체로 저장
df = pd.DataFrame([data])
df.to_json('output_df.json', orient='columns', indent=4, force_ascii=False) #같은 기능을 하는 옵션이지만 이름 다름

# %% [markdown]
# ## 5-3 Pandas Dataframe 데이터 추출

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터학", "경영학", "농학", "교육학", "영어영문학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}
df = pd.DataFrame(data) #여러개의 데이터가 들어있으므로 list가 아닌 그냥 데이터 불러옴
df

## DataFrame 인덱스 출력
print(df.index)

## DataFrame 컬럼 출력
print(df.columns)

## DataFrame 행 출력
print(df.values.tolist()) #파이썬의 리스트
print(df.values) #넘파이 리스트, 찎어보면 비슷해 보이지만 내부적으로 다름

## DataFrame 값 출력
print(df.values.flatten()) #구조를 뭉개고 쭉 일렬로 나열하는 메서드
# Out:
# RangeIndex(start=0, stop=5, step=1)
# Index(['이름', '학년', '학점', '학과', '동아리'], dtype='object')
# [['김철수', 1, 4.2, '컴퓨터학', '프로그래밍'], ['이영희', 2, 3.8, '경영학', '독서토론'], ['박민수', 3, 4.5, '농학', '로봇공학'], ['최지훈', 4, 3.9, '교육학', '봉사활동'], ['정소희', 2, 3.5, '영어영문학', '음악감상']]
# [['김철수' 1 4.2 '컴퓨터학' '프로그래밍']
#  ['이영희' 2 3.8 '경영학' '독서토론']
#  ['박민수' 3 4.5 '농학' '로봇공학']
#  ['최지훈' 4 3.9 '교육학' '봉사활동']
#  ['정소희' 2 3.5 '영어영문학' '음악감상']]
# ['김철수' 1 4.2 '컴퓨터학' '프로그래밍' '이영희' 2 3.8 '경영학' '독서토론' '박민수' 3 4.5 '농학'
#  '로봇공학' '최지훈' 4 3.9 '교육학' '봉사활동' '정소희' 2 3.5 '영어영문학' '음악감상']

# %% [markdown]
# ## 5-4 DataFrame 생성 방법

# %%
import pandas as pd
import json

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## 딕셔너리, csv, json으로 부터 DataFrame 생성
df1 = pd.DataFrame.from_dict(data)
df2 = pd.read_csv('students.csv')
df3 = pd.read_json('students.json')

## 세가지 방법 결과 비교
print(df1.shape) #가로세로으 ㅣ행렬인데 가로 세로로 몇개의 행과 열이 있는지 알려줌 shape
print(df2.shape)
print(df3.shape)
# Out:
# (5, 5)
# (5, 5)
# (5, 5)

# %% [markdown]
# ## 5-5 DataFrame 저장 방법

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## Dataframe 생성
df1 = pd.DataFrame(data)

## CSV, JSON 형식으로 저장
df.to_csv('students_scores.csv')
df.to_json('students_scores.json')

## HTML 형식으로 저장
html_table = df.to_html('students_scores.html') #괄호안에 파일명 넣어주면 with없이 바로 파일로 저장 가능
'''
print(html_table)
with open('students_scores.html', 'w') as f:
    f.write(html_table)
'''
# Out:
# "\nprint(html_table)\nwith open('students_scores.html', 'w') as f:\n    f.write(html_table)\n"

# %% [markdown]
# ## 5-6 실습 시나리오

# %% [markdown]
# ## 데이터 수집

# %%
import requests
#25.10.18 공공데이터포탈 접속불가라 실습 진행 불가
url = "http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getMinuDustFrcstDspth"
api_key = '[발급받은 인증키]'

params = {
    'serviceKey': api_key,
    'returnType': 'json',
    'numOfRows': '100',
    'pageNo': '1',
    'sidoName': '서울',
    'ver': '1.0'
}

## 데이터 수집
response = requests.get(url, params=params)

## 호출 성공/실패 출력

# %% [markdown]
# ## 데이터 프레임 생성

# %%
import pandas as pd

## requests로부터 response, body, item 항목 읽기

# %% [markdown]
# ## 다양항 형식으로 데이터 저장

# %%
df.to_csv('air_pollution.csv', index=False, encoding='utf-8')

## JSON 형식 데이터 저장

## EXCEL 형식 데이터 저장

## HTML 형식 데이터 저장
